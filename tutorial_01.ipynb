# %% [markdown]
# <a href="https://colab.research.google.com/github/rahafog/SDPC/blob/main/tutorial_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Tutorial Example #01

# %% [markdown]
# ### 1. Using a Ready-Made CNN model (Keras):

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings   
import random                
from sklearn.model_selection import train_test_split
from keras.datasets.cifar10 import load_data                           
from keras.models import Model                       # We will use Functional API.
from keras.layers import Dense, Dropout, Flatten
from keras.applications.mobilenet import MobileNet   # We will use a relatively small neural network.
from keras.applications.xception import Xception
from keras.applications.vgg16 import VGG16
from keras.applications.resnet import ResNet50
from keras.utils import to_categorical
from keras.optimizers import Adam, RMSprop, SGD
warnings.filterwarnings('ignore')                    # Turn the warnings off.
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
import os
import tensorflow as tf
import cv2
from tensorflow import keras
#from tensorflow.keras import layers, Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
import IPython

# %matplotlib inline

# %% [markdown]
# #### 1.1. Read in the data:

# %% [markdown]
# More information about the dataset can be found [here](http://shuoyang1213.me/WIDERFACE/).

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/WIDER_train.zip -d /content/drive/MyDrive/ColabNotebooks2 #you need to do it one time only
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_531.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_539.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_552.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_554.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_567.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_570.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_576.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_591.jpg
#   inflating: /content/drive/MyDrive/ColabNotebooks2/WIDER_test/4--Dancing/4_Dancing_Dancing_4_595.jpg
# ...

# %%
train_path='content/drive/My Drive/ColabNotebooks2/WIDER_train'
test_path='content/drive/My Drive/ColabNotebooks2/WIDER_test'

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen=ImageDataGenerator(rescale=1./255,
                                 shear_range=0.2,
                                 zoom_range=0.2,
                                 horizontal_flip=True)


Training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/ColabNotebooks2/WIDER_train',
                                               target_size=(244,244),
                                               batch_size=32,
                                               class_mode='categorical')
Test_set=train_datagen.flow_from_directory('/content/drive/MyDrive/ColabNotebooks2/WIDER_test',
                                               target_size=(244,244),
                                               batch_size=32,
                                              class_mode='categorical')
# Out:
# Found 12418 images belonging to 60 classes.
# Found 12418 images belonging to 60 classes.

# %%
# !git clone https://github.com/AntonMu/TrainYourOwnYOLO.git
# Out:
# Cloning into 'TrainYourOwnYOLO'...
# remote: Enumerating objects: 543, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 543 (delta 0), reused 2 (delta 0), pack-reused 540
# Receiving objects: 100% (543/543), 67.54 MiB | 34.30 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# %cd /content/TrainYourOwnYOLO/2_Training
# Out:
# /content/TrainYourOwnYOLO/2_Training

# %%
# %pwd
# Out:
# '/content/TrainYourOwnYOLO/2_Training'

# %%
# !cp -r /content/drive/MyDrive/ColabNotebooks2/WIDER_train /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images

# %%
# !cp -r /content/drive/MyDrive/training.txt /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/WIDER_train/

# %%
# !cp -r /content/drive/MyDrive/validation.txt /content/TrainYourOwnYOLO/Data/Source_Images/Training_Images/WIDER_train/

# %%
# !cat /content/TrainYourOwnYOLO/1_Image_Annotation/Convert_to_YOLO_format.py
# Out:
# from PIL import Image
# from os import path, makedirs
# import os
# import re
# import pandas as pd
# import sys
# import argparse
#
#
# def get_parent_dir(n=1):
#     """returns the n-th parent dicrectory of the current
#     working directory"""
#     current_path = os.path.dirname(os.path.abspath(__file__))
#     for k in range(n):
#         current_path = os.path.dirname(current_path)
#     return current_path
#
#
# sys.path.append(os.path.join(get_parent_dir(1), "Utils"))
# from Convert_Format import convert_vott_csv_to_yolo
#
# Data_Folder = os.path.join(get_parent_dir(1), "Data")
# VoTT_Folder = os.path.join(
#     Data_Folder, "Source_Images", "Training_Images", "vott-csv-export"
# )
# VoTT_csv = os.path.join(VoTT_Folder, "Annotations-export.csv")
# YOLO_filename = os.path.join(VoTT_Folder, "data_train.txt")
#
# model_folder = os.path.join(Data_Folder, "Model_Weights")
# classes_filename = os.path.join(model_folder, "data_classes.txt")
#
# if __name__ == "__main__":
# ...

# %%
# !python Download_and_Convert_YOLO_weights.py
# Out:
# ...
#
# | |                                  #              | 7568 Elapsed Time: 0:00:03
# Downloaded Raw yolov3.weights in 4.9 seconds
#
# 2021-05-06 21:13:13.682182: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# 2021-05-06 21:13:15.744633: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-06 21:13:15.792765: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-06 21:13:15.901136: E tensorflow/stream_executor/cuda/cuda_driver.cc:328] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-16a7bb96221e> in <module>()
# ----> 1 open (Train_YOLO.py)
#
# NameError: name 'Train_YOLO' is not defined
